# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'masterfinal.csv'

# %%
df = pd.read_csv('masterfinal.csv')

# %%
df.head()
# Out:
#                  track_id  popularity                album_name  \
# 0  000RDCYioLteXcutOjeweY        48.0                Teeje Week
# 1  013TFRzJWkT41RRSgSenfI        65.0                       amo
# 2  01BC4Xj5tfsfV8DLDrma7q        65.0  Speak Your Mind (Deluxe)
# 3  01MVOl9KtVTNfFiBU9I7dc        57.0      Days I Will Remember
# 4  01MVOl9KtVTNfFiBU9I7dc        57.0      Days I Will Remember
#
#    track_popularity track_genre genre_category           artist_name  \
# 0              62.0     hip-hop        hip hop         Jordan Sandhu
# 1              52.0   metalcore           rock  Bring Me The Horizon
# 2              65.0       house     electronic            Anne-Marie
# 3              58.0    acoustic       acoustic          Tyrone Wells
# 4              58.0   indie-pop            pop          Tyrone Wells
#
#                  track_name  acousticness  danceability  ...  \
# 0                Teeje Week        0.0583         0.679  ...
# 1  i don't know what to say        0.0154         0.499  ...
# 2                Ciao Adios        0.1360         0.694  ...
# 3      Days I Will Remember        0.2890         0.688  ...
# 4      Days I Will Remember        0.2890         0.688  ...
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0            0.0000  0.0    0.0825    -3.537   1.0       0.1900  161.721
# 1            0.0982  7.0    0.2460    -6.744   0.0       0.0550   92.449
# 2            0.0000  7.0    0.3220    -3.986   1.0       0.0934  106.098
# 3            0.0000  6.0    0.1890    -8.807   1.0       0.1050   98.017
# 4            0.0000  6.0    0.1890    -8.807   1.0       0.1050   98.017
#
#    time_signature  valence  loudness_binned
# 0             4.0    0.839             High
# 1             4.0    0.239             High
# 2             4.0    0.501             High
# 3             4.0    0.666             High
# 4             4.0    0.666             High
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          1567 non-null   object
#  1   popularity        1567 non-null   float64
#  2   album_name        1567 non-null   object
#  3   track_popularity  1567 non-null   float64
#  4   track_genre       1567 non-null   object
#  5   genre_category    1567 non-null   object
#  6   artist_name       1567 non-null   object
#  7   track_name        1567 non-null   object
#  8   acousticness      1567 non-null   float64
#  9   danceability      1567 non-null   float64
#  10  duration_ms       1567 non-null   float64
#  11  energy            1567 non-null   float64
#  12  instrumentalness  1567 non-null   float64
#  13  key               1567 non-null   float64
#  14  liveness          1567 non-null   float64
#  15  loudness          1567 non-null   float64
#  16  mode              1567 non-null   float64
#  17  speechiness       1567 non-null   float64
#  18  tempo             1567 non-null   float64
#  19  time_signature    1567 non-null   float64
#  20  valence           1567 non-null   float64
#  21  loudness_binned   1564 non-null   object
# dtypes: float64(15), object(7)
# memory usage: 269.5+ KB

# %%
df.shape
# Out:
# (1567, 22)

# %%
df.describe()
# Out:
#         popularity  track_popularity  acousticness  danceability  \
# count  1567.000000       1567.000000   1567.000000   1567.000000
# mean     59.712827         55.895980      0.266228      0.598627
# std      18.884416         16.603636      0.289602      0.155078
# min       6.000000          8.000000      0.000002      0.000000
# 25%      48.000000         47.000000      0.020850      0.498000
# 50%      61.000000         57.000000      0.158000      0.606000
# 75%      72.000000         68.000000      0.412500      0.716000
# max     100.000000         89.000000      0.995000      0.957000
#
#          duration_ms       energy  instrumentalness          key     liveness  \
# count    1567.000000  1567.000000       1567.000000  1567.000000  1567.000000
# mean   216500.006382     0.656796          0.100133     5.265475     0.196192
# std     60959.487363     0.215405          0.250225     3.523100     0.168052
# min     33203.000000     0.000020          0.000000     0.000000     0.021500
# 25%    184031.500000     0.521000          0.000000     2.000000     0.098100
# 50%    208653.000000     0.694000          0.000008     5.000000     0.124000
# 75%    235747.000000     0.822500          0.002415     8.000000     0.237500
# max    599746.000000     0.993000          0.997000    11.000000     0.981000
#
#           loudness         mode  speechiness        tempo  time_signature  \
# count  1567.000000  1567.000000  1567.000000  1567.000000     1567.000000
# mean     -6.865778     0.589662     0.084166   123.964540        3.929802
# std       3.895501     0.492052     0.084543    30.002308        0.341171
# min     -32.244000     0.000000     0.000000     0.000000        0.000000
# 25%      -8.207000     0.000000     0.037700    99.961000        4.000000
# 50%      -5.854000     1.000000     0.050500   123.960000        4.000000
# 75%      -4.483500     1.000000     0.088200   144.042500        4.000000
# max       0.175000     1.000000     0.902000   207.970000        5.000000
#
#            valence
# count  1567.000000
# mean      0.423228
# std       0.224595
# min       0.000000
# 25%       0.243000
# 50%       0.402000
# 75%       0.591000
# max       0.980000

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['popularity'], bins=10, kde=False, color='skyblue', edgecolor='black')
plt.title("Track Popularity Distribution")
plt.xlabel("Popularity Score")
plt.ylabel("Number of Tracks")
plt.xticks(range(0, 101, 10))
plt.tight_layout()
plt.show()

# %%
numeric_df = df.select_dtypes(include='number')
corr = numeric_df.corr()
plt.figure(figsize=(14, 10))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix of Numerical Features")
plt.show()

# %%
numeric_cols = numeric_df.columns

for col in numeric_cols:
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
# Popularity vs Key Features
key_features = ['danceability', 'loudness', 'instrumentalness']

for col in key_features:
    if df[col].nunique() <= 10:
        sns.boxplot(data=df, x=col, y='popularity')
    else:
        sns.scatterplot(data=df, x=col, y='popularity')
    plt.title(f"Popularity vs {col}")
    plt.xlabel(col)
    plt.ylabel("Popularity")
    plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    x='danceability',
    y='popularity',
    data=df,
    scatter_kws={'alpha': 0.3},
    line_kws={'color': 'red'}
)
plt.title("Danceability vs Popularity")
plt.xlabel("Danceability")
plt.ylabel("Popularity")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    x='loudness',
    y='popularity',
    data=df,
    scatter_kws={'alpha': 0.3},
    line_kws={'color': 'red'}
)
plt.title("Loudness vs Popularity")
plt.xlabel("Loudness")
plt.ylabel("Popularity")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    x='instrumentalness',
    y='popularity',
    data=df,
    scatter_kws={'alpha': 0.3},
    line_kws={'color': 'red'}
)
plt.title("Instrumentalness vs Popularity")
plt.xlabel("Instrumentalness")
plt.ylabel("Popularity")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(
    x='valence',
    y='popularity',
    data=df,
    scatter_kws={'alpha': 0.3},
    line_kws={'color': 'red'}
)
plt.title("Valence vs Popularity")
plt.xlabel("Instrumentalness")
plt.ylabel("Popularity")
plt.tight_layout()
plt.show()

# %%
corr = df.select_dtypes(include='number').corr()
top_corr_features = corr['popularity'].abs().sort_values(ascending=False)[1:6].index.tolist()

# Subset the DataFrame for pairplot
pairplot_data = df[top_corr_features + ['popularity']]
highlight_color = "#FF6F61"  

# Generate the pairplot
pairplot = sns.pairplot(pairplot_data)

# Highlight scatter plots that involve popularity
for i, feature in enumerate(top_corr_features + ['popularity']):
    for j, sub_feature in enumerate(top_corr_features + ['popularity']):
        ax = pairplot.axes[i, j]
        if 'popularity' in [feature, sub_feature] and feature != sub_feature:
            for artist in ax.collections:
                artist.set_color(highlight_color)

plt.suptitle("Pairplot: Top Correlated Features with Popularity (Highlighted)", y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# This pairplot visualizes the five features most strongly correlated with popularity: danceability, energy, valence, tempo, and loudness. The scatter plots involving popularity are highlighted in red to emphasize their importance.
#
# These plots help identify patterns and trends—such as positive or negative relationships—that can inform feature selection and modeling decisions.

# %%
#Loudness vs Popularity grouped by Loudness Level (Low, Medium, High)

# Bin loudness values
loudness_bins = [-60, -20, -10, 0]  # Decibel ranges typically seen in music
loudness_labels = ['Low', 'Medium', 'High']
df['loudness_binned'] = pd.cut(df['loudness'], bins=loudness_bins, labels=loudness_labels)

# Step 2: Plot the scatter plot with brighter colors and standard circles
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=df,
    x='loudness',
    y='popularity',
    hue='loudness_binned',
    palette='bright',
    alpha=0.9,
    s=70,
    marker='o'  # Use standard filled circle
)

# Step 3: Plot formatting
plt.title("Loudness vs Popularity (Grouped by Loudness Level)")
plt.xlabel("Loudness (dB)")
plt.ylabel("Popularity")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# This scatter plot shows how track loudness relates to popularity, using three grouped loudness levels:
#
# - Low (Blue): –60 dB to –20 dB → Very quiet tracks
#
# - Medium (Orange): –20 dB to –10 dB → Moderately loud tracks
#
# - High (Green): –10 dB to 0 dB → Loud tracks, near maximum volume
#
# Each point represents a track, and color helps distinguish how different loudness levels distribute across popularity. This insight helps determine if loudness should be considered a meaningful feature in clustering or modeling.

# %%
from scipy.stats import ttest_ind

key_features = ['danceability', 'loudness', 'instrumentalness', 'valence']
ttest_results = {}

# Hypothesis: High vs. Low [feature] differ in track popularity
for feature in key_features:
    if df[feature].nunique() > 1:
        median_value = df[feature].median()

        # Split into high/low groups based on feature value
        high_group = df[df[feature] > median_value]['track_popularity']
        low_group  = df[df[feature] <= median_value]['track_popularity']

        # Perform independent t-test
        stat, p = ttest_ind(high_group, low_group, nan_policy='omit')

        # Store result using scientific notation for precision
        ttest_results[feature] = format(p, ".4e")  # e.g., 2.34e-08

#Results
print("T-test results (p-values):")
for feature, p_value in ttest_results.items():
    print(f"{feature}: p-value = {p_value}")
# Out:
# T-test results (p-values):
# danceability: p-value = 8.3690e-21
# loudness: p-value = 3.8207e-09
# instrumentalness: p-value = 3.6525e-13
# valence: p-value = 1.0866e-03

# %% [markdown]
# ##### All 3 features have statistically significant effects on tracks popularity which are vaulable predictors.
#
# - Danceability
# Null Hypothesis (H₀):
# There is no difference in popularity between songs with high vs. low danceability.
#
# - Alternative Hypothesis (H₁):
# There is a significant difference in popularity between songs with high and low danceability.
#
# p-value: 8.3690e-21 → Highly significant
#
# Tracks with higher danceability tend to have significantly different (and likely higher) popularity than less danceable tracks.
#
# - Loudness
# H₀: Loudness level has no effect on popularity.
#
# H₁: Loudness level significantly affects popularity.
#
# p-value: 3.8207e-09 → Highly significant
#
# Louder tracks are significantly more popular on average than quieter ones.
#
# - Instrumentalness
# H₀: Instrumentalness has no impact on popularity.
#
# H₁: Instrumentalness significantly affects popularity.
#
# p-value: 3.6525e-13 → Highly significant
#
# Instrumental tracks tend to be less popular than vocal tracks (as shown by the negative correlation earlier), and this difference is statistically significant.

# %%
df.head()
# Out:
#                  track_id  popularity                album_name  \
# 0  000RDCYioLteXcutOjeweY        48.0                Teeje Week
# 1  013TFRzJWkT41RRSgSenfI        65.0                       amo
# 2  01BC4Xj5tfsfV8DLDrma7q        65.0  Speak Your Mind (Deluxe)
# 3  01MVOl9KtVTNfFiBU9I7dc        57.0      Days I Will Remember
# 4  01MVOl9KtVTNfFiBU9I7dc        57.0      Days I Will Remember
#
#    track_popularity track_genre genre_category           artist_name  \
# 0              62.0     hip-hop        hip hop         Jordan Sandhu
# 1              52.0   metalcore           rock  Bring Me The Horizon
# 2              65.0       house     electronic            Anne-Marie
# 3              58.0    acoustic       acoustic          Tyrone Wells
# 4              58.0   indie-pop            pop          Tyrone Wells
#
#                  track_name  acousticness  danceability  ...  \
# 0                Teeje Week        0.0583         0.679  ...
# 1  i don't know what to say        0.0154         0.499  ...
# 2                Ciao Adios        0.1360         0.694  ...
# 3      Days I Will Remember        0.2890         0.688  ...
# 4      Days I Will Remember        0.2890         0.688  ...
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0            0.0000  0.0    0.0825    -3.537   1.0       0.1900  161.721
# 1            0.0982  7.0    0.2460    -6.744   0.0       0.0550   92.449
# 2            0.0000  7.0    0.3220    -3.986   1.0       0.0934  106.098
# 3            0.0000  6.0    0.1890    -8.807   1.0       0.1050   98.017
# 4            0.0000  6.0    0.1890    -8.807   1.0       0.1050   98.017
#
#    time_signature  valence  loudness_binned
# 0             4.0    0.839             High
# 1             4.0    0.239             High
# 2             4.0    0.501             High
# 3             4.0    0.666             High
# 4             4.0    0.666             High
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (1567, 22)

# %%
df.to_csv('masterfinal.csv', index=False)
